# %% [markdown]
# # Data Prep

# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf
tf.config.run_functions_eagerly(True)
from matplotlib import pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from skimage import exposure
from PIL import Image
import skimage.measure
import os
import cv2
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
train_df = pd.read_csv("train.csv").iloc[:-2, :]
val_df = pd.read_csv("test.csv")

# %%
train_df
# Out:
#                                filename diagnostic
# 0      PAD-UFES-20/PAT_735_1391_683.png        ACK
# 1     PAD-UFES-20/PAT_1722_3214_672.png        ACK
# 2      PAD-UFES-20/PAT_730_1385_585.png        BCC
# 3        PAD-UFES-20/PAT_999_20_223.png        ACK
# 4      PAD-UFES-20/PAT_625_1184_994.png        SEK
# ...                                 ...        ...
# 1831   PAD-UFES-20/PAT_1261_896_349.png        SEK
# 1832   PAD-UFES-20/PAT_935_1781_341.png        BCC
# 1833   PAD-UFES-20/PAT_718_1358_919.png        BCC
# 1834  PAD-UFES-20/PAT_2153_4782_321.png        ACK
# 1835   PAD-UFES-20/PAT_930_1760_560.png        BCC
#
# [1836 rows x 2 columns]

# %%
val_df
# Out:
#                               filename diagnostic
# 0     PAD-UFES-20/PAT_967_1827_247.png        BCC
# 1     PAD-UFES-20/PAT_905_1721_327.png        BCC
# 2    PAD-UFES-20/PAT_1661_2956_357.png        ACK
# 3     PAD-UFES-20/PAT_1107_427_352.png        NEV
# 4     PAD-UFES-20/PAT_2077_4463_77.png        ACK
# ..                                 ...        ...
# 455  PAD-UFES-20/PAT_1922_3848_451.png        SEK
# 456  PAD-UFES-20/PAT_1468_3656_337.png        ACK
# 457    PAD-UFES-20/PAT_406_809_581.png        BCC
# 458  PAD-UFES-20/PAT_1573_2497_736.png        ACK
# 459      PAD-UFES-20/PAT_14_22_850.png        BCC
#
# [460 rows x 2 columns]

# %%
BATCH_SIZE = 1
IMG_SIZE = 224
NUM_CLASSES = train_df["diagnostic"].nunique()
TRAIN_RATIO = 0.8

# %%
datagen = ImageDataGenerator (
    rescale = 1/255.,
)

training_generator = datagen.flow_from_dataframe (
    train_df,
    x_col = "filename",
    y_col = "diagnostic",
    batch_size = BATCH_SIZE,
    target_size = ((IMG_SIZE, IMG_SIZE)),
    shuffle=False
)

val_generator = datagen.flow_from_dataframe (
    val_df,
    x_col = "filename",
    y_col = "diagnostic",
    batch_size = BATCH_SIZE,
    target_size = ((IMG_SIZE, IMG_SIZE)),
)
# Out:
# Found 1836 validated image filenames belonging to 6 classes.
# Found 460 validated image filenames belonging to 6 classes.

# %%
# plt.hist(training_generator.labels)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
train_df.diagnostic.value_counts().sort_index().plot.bar(label="training")
val_df.diagnostic.value_counts().sort_index().plot.bar(label="validation", color="orange")
plt.xlabel("Diagnosis")
plt.ylabel("Number of samples")
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %%
train_df.diagnostic.value_counts().sort_index()
# Out:
# ACK    584
# BCC    674
# MEL     42
# NEV    195
# SCC    153
# SEK    188
# Name: diagnostic, dtype: int64

# %%
plt.hist(val_generator.labels)
# Out:
# (array([146.,   0., 169.,   0.,  10.,   0.,  49.,   0.,  39.,  47.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.utils import class_weight 
import numpy as np

class_weights = class_weight.compute_class_weight(
    class_weight = 'balanced', 
    classes = np.unique(training_generator.classes), 
    y = training_generator.classes)
class_weights = dict(zip(np.unique(training_generator.classes), class_weights))
class_weights
# Out:
# {0: 0.523972602739726,
#  1: 0.4540059347181009,
#  2: 7.285714285714286,
#  3: 1.5692307692307692,
#  4: 2.0,
#  5: 1.627659574468085}

# %%
classes = train_df["diagnostic"].unique()

# %% [markdown]
# # Saliency

# %%
from skimage.transform import resize

# %%
@tf.function
def normalize(heatmap):
    num = heatmap - tf.reduce_min(heatmap)
    deno = (tf.reduce_max(heatmap) - tf.reduce_min(heatmap))
    if deno == 0:
        return heatmap
    heatmap = num / deno
    return heatmap

# %%
@tf.function
def compute_saliency_map(model, image, eps=1e-8):
    gradModel = tf.keras.models.Model(
        inputs=[model.inputs],
        outputs=model.outputs
    )

    with tf.GradientTape(persistent = True) as tape:
        input_image = tf.cast(image, tf.float32)
        tape.watch(input_image)
        predictions = model(input_image)
        classid = tf.argmax(predictions[0])
        loss = predictions[:, classid]

    gradient = tape.gradient(loss, image)
    gradient = tf.reduce_max(gradient, axis=-1)
    heatmap = gradient.numpy()        

    heatmap = tf.squeeze(heatmap)
    heatmap = normalize(heatmap)
    return heatmap

# %%
@tf.function
def generate_saliency_batch(imgs, global_model):
    fused_heatmaps = []
    for image in imgs:
        heatmap = compute_saliency_map(global_model, tf.expand_dims(image, axis=0))
        fused_heatmaps.append(heatmap)

    return tf.convert_to_tensor(fused_heatmaps, tf.float32)

# %%
def overlay_heatmap(heatmap, image, alpha=0.5,colormap=cv2.COLORMAP_JET):
    heatmap = cv2.cvtColor(cv2.applyColorMap((heatmap * 255.).astype("uint8"), colormap), cv2.COLOR_BGR2RGB)
    output = cv2.addWeighted((image * 255.).astype("uint8"), alpha, heatmap, 1 - alpha, 0)
    return output

# %% [markdown]
# # Train Teacher branch - DenseNet

# %%
from tensorflow.keras.applications.densenet import DenseNet121

# %%
def build_DenseNet_model():

    backbone_model = DenseNet121(
        include_top=False,
        weights="imagenet",
        input_tensor=tf.keras.layers.Input(shape=(IMG_SIZE,IMG_SIZE,3))
    )

    pooling  = tf.keras.layers.GlobalMaxPooling2D()(backbone_model.output)
    
    dense = tf.keras.layers.Dense(units = 1024, kernel_regularizer= tf.keras.regularizers.l2(0.0001))(pooling)
    batch_norm = tf.keras.layers.BatchNormalization()(dense)
    leaky_relu = tf.keras.layers.LeakyReLU()(batch_norm)
    
    classifier = tf.keras.layers.Dense(units = NUM_CLASSES, activation = 'softmax')(leaky_relu)
    model = tf.keras.models.Model(inputs = backbone_model.input, outputs = classifier)
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    model.compile(optimizer=optimizer,loss='categorical_crossentropy', metrics = ['accuracy'])
    
    # Added to improve gradcam output
    for layer in model.layers:
        if isinstance(layer, tf.keras.layers.ZeroPadding2D):
            continue
        layer.padding = "same"
            
    return model

# %%
teacher_model = build_DenseNet_model()

# %%
teacher_model.load_weights("models_saliency/Teacher/160_1.021_0.691.h5")

# %%
EPOCHS = 100

# %%
earlystop = tf.keras.callbacks.EarlyStopping(patience=10)
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=5, 
                                            verbose=1, 
                                            factor=0.2, 
                                            min_lr=1e-6)
checkpoint = tf.keras.callbacks.ModelCheckpoint('models_saliency/Global/best_model.h5', monitor='val_accuracy', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only = True)
mycallbacks = [earlystop, learning_rate_reduction,checkpoint]

# %%
history = teacher_model.fit_generator(
    training_generator,
    epochs = EPOCHS,
    validation_data = val_generator,
    callbacks = mycallbacks,
    class_weight=class_weights
)

# %%
# Plot accuracy graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Plot loss graph
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
val_loss, val_accuracy = teacher_model.evaluate(val_generator)
print(val_loss, val_accuracy)

# %%
global_model.save_weights(f"models_saliency/Global/190_{val_loss:.3f}_{val_accuracy:.3f}.h5")

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix

y_pred_all = []
y_test_all = []
labels = list(val_generator.class_indices.keys())
print(labels)

STEPS_PER_EPOCH = val_generator.samples//BATCH_SIZE
for i in range(STEPS_PER_EPOCH):
    print(f"\r{i}/{STEPS_PER_EPOCH}", end = "")
    x, y_test = val_generator.next()
    y_pred = global_model(x, training=False)
    for y in y_test:
        y_test_all.append(tf.argmax(y))
        
    for y in y_pred:
        y_pred_all.append(tf.argmax(y))
        
cm = confusion_matrix(y_test_all, y_pred_all)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

disp.plot(cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# # Initialize student model - MobileNet

# %%
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2

# %%
def build_Mobilenet_model():
    backbone_model = MobileNetV2(
        include_top=False,
        weights="imagenet",
        input_tensor=tf.keras.layers.Input(shape=(IMG_SIZE,IMG_SIZE,3))
    )

    pooling  = tf.keras.layers.GlobalMaxPooling2D()(backbone_model.output)
    
    dense = tf.keras.layers.Dense(units = 1024, kernel_regularizer= tf.keras.regularizers.l2(0.0001))(pooling)
    batch_norm = tf.keras.layers.BatchNormalization()(dense)
    leaky_relu = tf.keras.layers.LeakyReLU()(batch_norm)
    
    classifier = tf.keras.layers.Dense(units = NUM_CLASSES, activation = 'softmax')(leaky_relu)
    model = tf.keras.models.Model(inputs = backbone_model.input, outputs = classifier)
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    model.compile(optimizer=optimizer,loss='categorical_crossentropy', metrics = ['accuracy'])
    
    # Added to improve gradcam output
    for layer in model.layers:
        if isinstance(layer, tf.keras.layers.ZeroPadding2D):
            continue
        layer.padding = "same"
            
    return model

# %%
def dist_loss(map1, map2):
    return tf.reduce_mean(tf.keras.losses.mean_squared_error(map1, map2))

# %%
class Distiller(tf.keras.Model):
    def __init__(self, student):
        super().__init__()
#         self.teacher = teacher
        self.student = student

    def compile(
        self,
        optimizer,
        metrics,
        student_loss_fn,
        distillation_loss_fn,
        alpha=0.1,
    ):
        """ Configure the distiller.

        Args:
            optimizer: Keras optimizer for the student weights
            metrics: Keras metrics for evaluation
            student_loss_fn: Loss function of difference between student
                predictions and ground-truth
            distillation_loss_fn: Loss function of difference between soft
                student predictions and soft teacher predictions
            alpha: weight to student_loss_fn and 1-alpha to distillation_loss_fn
            temperature: Temperature for softening probability distributions.
                Larger temperature gives softer distributions.
        """
        super().compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        
    def train_step(self, data):
        # Unpack data
        # Ignoring sample weights here (consider later if possible)
        x, y, sample_weights = data        

        # Forward pass of teacher
        maps_teacher = generate_saliency_batch(x, teacher_model) # Using the global teacher variable

        with tf.GradientTape() as tape:
            # Forward pass of student
            student_predictions = self.student(x, training=True)
            maps_student = generate_saliency_batch(x, self.student)

            # Compute losses
            student_loss = self.student_loss_fn(y, student_predictions)

            # Compute scaled distillation loss from https://arxiv.org/abs/1503.02531
            # The magnitudes of the gradients produced by the soft targets scale
            # as 1/T^2, multiply them by T^2 when using both hard and soft targets.
            distillation_loss = tf.convert_to_tensor([self.distillation_loss_fn(a, b) for (a, b) in zip(maps_teacher, maps_student)])

            loss = self.alpha * student_loss + (1 - self.alpha) * distillation_loss

        # Compute gradients
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update the metrics configured in `compile()`.
        self.compiled_metrics.update_state(y, student_predictions)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update(
            {"student_loss": student_loss, "distillation_loss": distillation_loss}
        )
        return results

    def test_step(self, data):
        # Unpack the data
        x, y = data

        # Compute predictions
        y_prediction = self.student(x, training=False)

        # Calculate the loss
        student_loss = self.student_loss_fn(y, y_prediction)

        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update({"student_loss": student_loss})
        return results
    
#     def save_weights(filepath, **kwargs):
#         self.student.save_weights(filepath)

# %%
student_model = build_Mobilenet_model()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
distiller = Distiller(student=student_model)
distiller.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    metrics=['accuracy'],
    student_loss_fn=tf.keras.losses.CategoricalCrossentropy(),
    distillation_loss_fn=dist_loss,
    alpha=0.5,
)

# %%
distiller.load_weights("models_saliency/Student/46_3.791_0.707.h5")

# %%
EPOCHS = 100

# %%
earlystop = tf.keras.callbacks.EarlyStopping(patience=10)
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=5, 
                                            verbose=1, 
                                            factor=0.2, 
                                            min_lr=1e-6)
checkpoint = tf.keras.callbacks.ModelCheckpoint('models_saliency/Student/{epoch:02d}_{val_student_loss:.3f}_{val_accuracy:.3f}.h5', monitor='val_accuracy', verbose=1, 
                             mode='max', save_weights_only = True)
mycallbacks = [earlystop, learning_rate_reduction,checkpoint]
mycallbacks = [learning_rate_reduction,checkpoint]

# %%
history = distiller.fit_generator(
    training_generator,
#     steps_per_epoch=1,
#     validation_steps=1,
    epochs = EPOCHS,
    initial_epoch=32,
    validation_data = val_generator,
    callbacks = mycallbacks,
    class_weight=class_weights
)
# Out:
# Epoch 33/100
# C:\Users\vaash\AppData\Local\Temp\ipykernel_3416\2077248917.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = distiller.fit_generator(
# C:\Users\vaash\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\structured_function.py:264: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
#    1/1836 [..............................] - ETA: 3:29:27 - accuracy: 0.0000e+00 - student_loss: 1.7918 - distillation_loss: 0.0060
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 history = distiller.fit_generator(
#       2     training_generator,
#       3 #     steps_per_epoch=1,
#       4 #     validation_steps=1,
#       5     epochs = EPOCHS,
#       6     initial_epoch=32,
#       7     validation_data = val_generator,
#       8     callbacks = mycallbacks,
#       9     class_weight=class_weights
#      10 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\training.py:2507, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2495 """Fits the model on data yielded batch-by-batch by a Python generator.
#    2496
#    2497 DEPRECATED:
#    2498   `Model.fit` now supports generators, so there is no longer any need to
#    2499   use this endpoint.
#    2500 """
#    2501 warnings.warn(
#    2502     "`Model.fit_generator` is deprecated and "
#    2503     "will be removed in a future version. "
#    2504     "Please use `Model.fit`, which supports generators.",
#    2505     stacklevel=2,
#    2506 )
# -> 2507 return self.fit(
#    2508     generator,
#    2509     steps_per_epoch=steps_per_epoch,
#    2510     epochs=epochs,
#    2511     verbose=verbose,
#    2512     callbacks=callbacks,
#    2513     validation_data=validation_data,
#    2514     validation_steps=validation_steps,
#    2515     validation_freq=validation_freq,
#    2516     class_weight=class_weight,
#    2517     max_queue_size=max_queue_size,
#    2518     workers=workers,
#    2519     use_multiprocessing=use_multiprocessing,
#    2520     shuffle=shuffle,
#    2521     initial_epoch=initial_epoch,
#    2522 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\training.py:1160, in Model.make_train_function.<locals>.train_function(iterator)
#    1158 def train_function(iterator):
#    1159     """Runs a training execution with a single step."""
# -> 1160     return step_function(self, iterator)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\training.py:1146, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1142     run_step = tf.function(
#    1143         run_step, jit_compile=True, reduce_retracing=True
#    1144     )
#    1145 data = next(iterator)
# -> 1146 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1147 outputs = reduce_per_replica(
#    1148     outputs, self.distribute_strategy, reduction="first"
#    1149 )
#    1150 return outputs
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\distribute\distribute_lib.py:1315, in StrategyBase.run(***failed resolving arguments***)
#    1310 with self.scope():
#    1311   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1312   # applied when the caller is also in Eager mode.
#    1313   fn = autograph.tf_convert(
#    1314       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1315   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\distribute\distribute_lib.py:2891, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2889   kwargs = {}
#    2890 with self._container_strategy().scope():
# -> 2891   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\distribute\distribute_lib.py:3692, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3690 def _call_for_each_replica(self, fn, args, kwargs):
#    3691   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3692     return fn(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\autograph\impl\api.py:595, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     593 def wrapper(*args, **kwargs):
#     594   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595     return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\training.py:1135, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1134 def run_step(data):
# -> 1135     outputs = model.train_step(data)
#    1136     # Ensure counter is updated only if `train_step` succeeds.
#    1137     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# Input In [24], in Distiller.train_step(self, data)
#      41 with tf.GradientTape() as tape:
#      42     # Forward pass of student
#      43     student_predictions = self.student(x, training=True)
# ---> 44     maps_student = generate_saliency_batch(x, self.student)
#      46     # Compute losses
#      47     student_loss = self.student_loss_fn(y, student_predictions)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\def_function.py:892, in Function.__call__(self, *args, **kwds)
#     890 if self._run_functions_eagerly:
#     891   with trace.Trace(self._name, tf_function_call="eager"):
# --> 892     return self._python_function(*args, **kwds)
#     894 # Only count the statistics the first time, before initialization took
#     895 # place.
#     896 if self._created_variables is None:
#
# Input In [15], in generate_saliency_batch(imgs, global_model)
#       3 fused_heatmaps = []
#       4 for image in imgs:
# ----> 5     heatmap = compute_saliency_map(global_model, tf.expand_dims(image, axis=0))
#       6     fused_heatmaps.append(heatmap)
#       8 return tf.convert_to_tensor(fused_heatmaps, tf.float32)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\def_function.py:892, in Function.__call__(self, *args, **kwds)
#     890 if self._run_functions_eagerly:
#     891   with trace.Trace(self._name, tf_function_call="eager"):
# --> 892     return self._python_function(*args, **kwds)
#     894 # Only count the statistics the first time, before initialization took
#     895 # place.
#     896 if self._created_variables is None:
#
# Input In [14], in compute_saliency_map(model, image, eps)
#       9 input_image = tf.cast(image, tf.float32)
#      10 tape.watch(input_image)
# ---> 11 predictions = model(input_image)
#      12 classid = tf.argmax(predictions[0])
#      13 loss = predictions[:, classid]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\training.py:557, in Model.__call__(self, *args, **kwargs)
#     553         super().__call__(inputs, *copied_args, **copied_kwargs)
#     555     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 557 return super().__call__(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
#    1100     self._handle_activity_regularization(inputs, outputs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\functional.py:510, in Functional.call(self, inputs, training, mask)
#     491 @doc_controls.do_not_doc_inheritable
#     492 def call(self, inputs, training=None, mask=None):
#     493     """Calls the model on new inputs.
#     494
#     495     In this case `call` just reapplies
#    (...)
#     508         a list of tensors if there are more than one outputs.
#     509     """
# --> 510     return self._run_internal_graph(inputs, training=training, mask=mask)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\functional.py:667, in Functional._run_internal_graph(self, inputs, training, mask)
#     664     continue  # Node is not computable, try skipping.
#     666 args, kwargs = node.map_arguments(tensor_dict)
# --> 667 outputs = node.layer(*args, **kwargs)
#     669 # Update tensor_dict.
#     670 for x_id, y in zip(
#     671     node.flat_output_ids, tf.nest.flatten(outputs)
#     672 ):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
#    1100     self._handle_activity_regularization(inputs, outputs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\layers\normalization\batch_normalization.py:850, in BatchNormalizationBase.call(self, inputs, training)
#     847         return outputs
#     849 if self.fused:
# --> 850     outputs = self._fused_batch_norm(inputs, training=training)
#     851     if self.virtual_batch_size is not None:
#     852         # Currently never reaches here since fused_batch_norm does not
#     853         # support virtual batching
#     854         outputs = undo_virtual_batching(outputs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\layers\normalization\batch_normalization.py:660, in BatchNormalizationBase._fused_batch_norm(self, inputs, training)
#     648 def _fused_batch_norm_inference():
#     649     return tf.compat.v1.nn.fused_batch_norm(
#     650         inputs,
#     651         gamma,
#    (...)
#     657         data_format=self._data_format,
#     658     )
# --> 660 output, mean, variance = control_flow_util.smart_cond(
#     661     training, _fused_batch_norm_training, _fused_batch_norm_inference
#     662 )
#     663 variance = _maybe_add_or_remove_bessels_correction(
#     664     variance, remove=True
#     665 )
#     667 training_value = control_flow_util.constant_value(training)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\control_flow_util.py:108, in smart_cond(pred, true_fn, false_fn, name)
#     106 if isinstance(pred, tf.Variable):
#     107     return tf.cond(pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 108 return tf.__internal__.smart_cond.smart_cond(
#     109     pred, true_fn=true_fn, false_fn=false_fn, name=name
#     110 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\smart_cond.py:54, in smart_cond(pred, true_fn, false_fn, name)
#      52     return true_fn()
#      53   else:
# ---> 54     return false_fn()
#      55 else:
#      56   return control_flow_ops.cond(pred, true_fn=true_fn, false_fn=false_fn,
#      57                                name=name)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\layers\normalization\batch_normalization.py:649, in BatchNormalizationBase._fused_batch_norm.<locals>._fused_batch_norm_inference()
#     648 def _fused_batch_norm_inference():
# --> 649     return tf.compat.v1.nn.fused_batch_norm(
#     650         inputs,
#     651         gamma,
#     652         beta,
#     653         mean=self.moving_mean,
#     654         variance=self.moving_variance,
#     655         epsilon=self.epsilon,
#     656         is_training=False,
#     657         data_format=self._data_format,
#     658     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\nn_impl.py:1680, in fused_batch_norm(x, scale, offset, mean, variance, epsilon, data_format, is_training, name, exponential_avg_factor)
#    1678 x = ops.convert_to_tensor(x, name="input")
#    1679 scale = ops.convert_to_tensor(scale, name="scale")
# -> 1680 offset = ops.convert_to_tensor(offset, name="offset")
#    1681 if mean is None:
#    1682   mean = constant_op.constant([])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:1638, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1629       raise RuntimeError(
#    1630           _add_error_prefix(
#    1631               f"Conversion function {conversion_func!r} for type "
#    (...)
#    1634               f"actual = {ret.dtype.base_dtype.name}",
#    1635               name=name))
#    1637 if ret is None:
# -> 1638   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1640 if ret is NotImplemented:
#    1641   continue
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\resource_variable_ops.py:2105, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2104 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2105   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\resource_variable_ops.py:1467, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1465   return self.read_value().op.inputs[0]
#    1466 else:
# -> 1467   return self.value()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\resource_variable_ops.py:582, in BaseResourceVariable.value(self)
#     580   return self._cached_value
#     581 with ops.colocate_with(None, ignore_existing=True):
# --> 582   return self._read_variable_op()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\resource_variable_ops.py:704, in BaseResourceVariable._read_variable_op(self, no_copy)
#     702       result = read_and_set_handle(no_copy)
#     703 else:
# --> 704   result = read_and_set_handle(no_copy)
#     706 if not context.executing_eagerly():
#     707   # Note that if a control flow context is active the input of the read op
#     708   # might not actually be the handle. This line bypasses it.
#     709   tape.record_operation(
#     710       "ReadVariableOp", [result], [self.handle],
#     711       backward_function=lambda x: [x],
#     712       forward_function=lambda x: [x])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\resource_variable_ops.py:694, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     692 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     693   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 694 result = gen_resource_variable_ops.read_variable_op(
#     695     self.handle, self._dtype)
#     696 _maybe_set_handle_data(self._dtype, self.handle, result)
#     697 return result
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:524, in read_variable_op(resource, dtype, name)
#     522 if tld.is_eager:
#     523   try:
# --> 524     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     525       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     526     return _result
#     527   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Plot accuracy graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Plot loss graph
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
val_loss, val_accuracy = distiller.evaluate(val_generator)
print(val_loss, val_accuracy)

# %% [markdown]
# # Visualize and Save attention maps

# %%
training_generator.class_indices

# %%
images, labels = training_generator.next()

# %%
for i in images:
    print(i.sum())

# %%
print("True labels: ", tf.argmax(labels, axis = 1).numpy())
print("Predictions: ", tf.argmax(distiller.student(images), axis=1).numpy())

# %%
filepaths = training_generator.filepaths[4:8]
filepaths

# %%
def get_images(filepaths):
    imgs = []
    for path in filepaths:
        img = Image.open(path).convert('RGB')
        img = np.array(img)
        img = resize(img, (IMG_SIZE, IMG_SIZE, 3))
        imgs.append(img)
    return np.array(imgs)

# %%
images = get_images(filepaths)

# %%
# %%time
heatmaps = generate_saliency_batch(images, distiller.student)

# %%
overlaid_images = [overlay_heatmap(hmap.numpy(), img, alpha=0.8) for (hmap, img) in zip(heatmaps, images)]

# %%
plt.imshow(np.hstack(images))

# %%
plt.imshow(np.hstack(heatmaps), cmap="jet")

# %%
plt.imshow(np.hstack(overlaid_images))

# %%
OUTPUT_FOLDER = "MIPS_teacher"
# !mkdir "$OUTPUT_FOLDER"

# %%
IMAGE_START = 8

# %%
# !mkdir "$OUTPUT_FOLDER/images"
for img_id, (img, label) in enumerate(zip(images, labels)):
    plt.imsave(f"{OUTPUT_FOLDER}/images/{img_id + IMAGE_START}_{tf.argmax(label)}.jpg", img, cmap="jet")

# %%
# !mkdir "$OUTPUT_FOLDER/gradcams"
for img_id, (img, label) in enumerate(zip(heatmaps, labels)):
    plt.imsave(f"{OUTPUT_FOLDER}/gradcams/{img_id + IMAGE_START}_{tf.argmax(label)}.jpg", img, cmap="jet")

# %%
# !mkdir "$OUTPUT_FOLDER/overlaid"
for img_id, (img, label) in enumerate(zip(overlaid_images, labels)):
    plt.imsave(f"{OUTPUT_FOLDER}/overlaid/{img_id + IMAGE_START}_{tf.argmax(label)}.jpg", img, cmap="jet")

# %% [markdown]
# # Metrics

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import roc_curve, roc_auc_score, precision_score, recall_score, f1_score, balanced_accuracy_score, classification_report

# %%
def get_metrics(prediction_function):
    y_pred = []
    y_pred_max = []
    y_true = []

    num_steps = val_generator.samples//BATCH_SIZE

    for i in range(num_steps):
        print(f"\r{i}/{num_steps}", end="")
        x, y = val_generator.next()
        y_pred_batch = prediction_function(x, y)
        y_pred_batch/= tf.reshape(
            tf.reduce_sum(y_pred_batch, axis=1), 
            (-1, 1)
        )
        y_pred += list(y_pred_batch.numpy())
        y_pred_max += list(tf.argmax(y_pred_batch, axis=1).numpy())
        y_true += list(tf.argmax(y, axis=1).numpy())
    
    print()
    acc = accuracy_score(y_true, y_pred_max)
    print("Accuracy: ", acc)
    
    precision = precision_score(y_true, y_pred_max, average="weighted")
    print("Precision: ", precision)
    
    recall = recall_score(y_true, y_pred_max, average="weighted")
    print("Recall: ", recall)
    
    f1 = f1_score(y_true, y_pred_max, average="weighted")
    print("F1: ", f1)

    auc = roc_auc_score(y_true, y_pred, average="weighted", multi_class='ovr')
    print("AUC: ", auc)
#     return y_true, y_pred
    return classification_report(y_true, y_pred_max, digits=5)

# %%
def pred_student(images, labels):
    return distiller.student(images, training=False)

# %%
class_report_distilled = get_metrics(pred_student)
print(class_report_distilled)
# Out:
# 28/460
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 class_report_distilled = get_metrics(pred_student)
#       2 print(class_report_distilled)
#
# Input In [31], in get_metrics(prediction_function)
#       9 print(f"\r{i}/{num_steps}", end="")
#      10 x, y = val_generator.next()
# ---> 11 y_pred_batch = prediction_function(x, y)
#      12 y_pred_batch/= tf.reshape(
#      13     tf.reduce_sum(y_pred_batch, axis=1),
#      14     (-1, 1)
#      15 )
#      16 y_pred += list(y_pred_batch.numpy())
#
# Input In [32], in pred_student(images, labels)
#       1 def pred_student(images, labels):
# ----> 2     return distiller.student(images, training=False)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\training.py:557, in Model.__call__(self, *args, **kwargs)
#     553         super().__call__(inputs, *copied_args, **copied_kwargs)
#     555     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 557 return super().__call__(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
#    1100     self._handle_activity_regularization(inputs, outputs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\functional.py:510, in Functional.call(self, inputs, training, mask)
#     491 @doc_controls.do_not_doc_inheritable
#     492 def call(self, inputs, training=None, mask=None):
#     493     """Calls the model on new inputs.
#     494
#     495     In this case `call` just reapplies
#    (...)
#     508         a list of tensors if there are more than one outputs.
#     509     """
# --> 510     return self._run_internal_graph(inputs, training=training, mask=mask)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\functional.py:667, in Functional._run_internal_graph(self, inputs, training, mask)
#     664     continue  # Node is not computable, try skipping.
#     666 args, kwargs = node.map_arguments(tensor_dict)
# --> 667 outputs = node.layer(*args, **kwargs)
#     669 # Update tensor_dict.
#     670 for x_id, y in zip(
#     671     node.flat_output_ids, tf.nest.flatten(outputs)
#     672 ):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
#    1100     self._handle_activity_regularization(inputs, outputs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\layers\convolutional\depthwise_conv2d.py:161, in DepthwiseConv2D.call(self, inputs)
#     160 def call(self, inputs):
# --> 161     outputs = backend.depthwise_conv2d(
#     162         inputs,
#     163         self.depthwise_kernel,
#     164         strides=self.strides,
#     165         padding=self.padding,
#     166         dilation_rate=self.dilation_rate,
#     167         data_format=self.data_format,
#     168     )
#     170     if self.use_bias:
#     171         outputs = backend.bias_add(
#     172             outputs, self.bias, data_format=self.data_format
#     173         )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\backend.py:6315, in depthwise_conv2d(x, depthwise_kernel, strides, padding, data_format, dilation_rate)
#    6312 else:
#    6313     strides = (1, 1) + strides
# -> 6315 x = tf.compat.v1.nn.depthwise_conv2d(
#    6316     x,
#    6317     depthwise_kernel,
#    6318     strides=strides,
#    6319     padding=padding,
#    6320     rate=dilation_rate,
#    6321     data_format=tf_data_format,
#    6322 )
#    6323 if data_format == "channels_first" and tf_data_format == "NHWC":
#    6324     x = tf.compat.v1.transpose(x, (0, 3, 1, 2))  # NHWC -> NCHW
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\nn_impl.py:887, in depthwise_conv2d(input, filter, strides, padding, rate, name, data_format, dilations)
#     878 def op(input_converted, _, padding):
#     879   return nn_ops.depthwise_conv2d_native(
#     880       input=input_converted,
#     881       filter=filter,
#    (...)
#     884       data_format=data_format,
#     885       name=name)
# --> 887 return nn_ops.with_space_to_batch(
#     888     input=input,
#     889     filter_shape=array_ops.shape(filter),
#     890     dilation_rate=rate,
#     891     padding=padding,
#     892     data_format=data_format,
#     893     op=op)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\nn_ops.py:724, in with_space_to_batch(input, dilation_rate, padding, op, filter_shape, spatial_dims, data_format)
#     714   return lambda inp, _: op(inp, num_spatial_dims, padding)
#     716 new_op = _WithSpaceToBatch(
#     717     input_shape,
#     718     dilation_rate,
#    (...)
#     722     spatial_dims=spatial_dims,
#     723     data_format=data_format)
# --> 724 return new_op(input, None)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\nn_ops.py:902, in _WithSpaceToBatch.__call__(self, inp, filter)
#     901 def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 902   return self.call(inp, filter)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\nn_ops.py:714, in with_space_to_batch.<locals>.build_op.<locals>.<lambda>(inp, _)
#     713 def build_op(num_spatial_dims, padding):
# --> 714   return lambda inp, _: op(inp, num_spatial_dims, padding)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\nn_impl.py:879, in depthwise_conv2d.<locals>.op(input_converted, _, padding)
#     878 def op(input_converted, _, padding):
# --> 879   return nn_ops.depthwise_conv2d_native(
#     880       input=input_converted,
#     881       filter=filter,
#     882       strides=strides,
#     883       padding=padding,
#     884       data_format=data_format,
#     885       name=name)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\nn_ops.py:3037, in depthwise_conv2d_native(input, filter, strides, padding, data_format, dilations, name)
#    2984 r"""Computes a 2-D depthwise convolution.
#    2985
#    2986 Given an input tensor of shape `[batch, in_height, in_width, in_channels]`
#    (...)
#    3034   A `Tensor`. Has the same type as `input`.
#    3035 """
#    3036 padding, explicit_paddings = convert_padding(padding)
# -> 3037 return gen_nn_ops.depthwise_conv2d_native(
#    3038     input,
#    3039     filter,
#    3040     strides,
#    3041     padding,
#    3042     explicit_paddings=explicit_paddings,
#    3043     data_format=data_format,
#    3044     dilations=dilations,
#    3045     name=name)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\gen_nn_ops.py:2388, in depthwise_conv2d_native(input, filter, strides, padding, explicit_paddings, data_format, dilations, name)
#    2386 if tld.is_eager:
#    2387   try:
# -> 2388     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2389       _ctx, "DepthwiseConv2dNative", name, input, filter, "strides",
#    2390       strides, "padding", padding, "explicit_paddings", explicit_paddings,
#    2391       "data_format", data_format, "dilations", dilations)
#    2392     return _result
#    2393   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
def pred_teacher(images, labels):
    return teacher_model(images, training=False)

# %%
class_report_teacher = get_metrics(pred_teacher)
print(class_report_teacher)

# %% [markdown]
# # Visualize and Save attention maps

# %%
student_self = build_Mobilenet_model()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
predicted = -1
while predicted != 5:
    images, labels = training_generator.next()
    predicted = tf.argmax(labels, axis=-1)[0]

# %%
tf.argmax(labels, axis=-1)
# Out:
# <tf.Tensor: shape=(1,), dtype=int64, numpy=array([5], dtype=int64)>

# %% [markdown]
# ## Self trained

# %%
student_self.load_weights("models_self/94_1.567_0.611.h5")

# %%
# %%time
self_heatmaps = generate_saliency_batch(images, student_self)
# Out:
# CPU times: total: 109 ms
# Wall time: 128 ms

# %%
plt.imshow(np.hstack(images))

# %%
plt.imshow(np.hstack(self_heatmaps), cmap="jet")

# %% [markdown]
# ## Normal kd

# %%
distiller.load_weights("models_normal/Student/54_1.018_0.654.h5")

# %%
# %%time
vanilla_heatmaps = generate_saliency_batch(images, distiller.student)
# Out:
# CPU times: total: 109 ms
# Wall time: 132 ms

# %%
plt.imshow(np.hstack(vanilla_heatmaps), cmap="jet")

# %% [markdown]
# ## saliency kd

# %%
distiller.load_weights("models_saliency/Student/46_3.791_0.707.h5")

# %%
# %%time
fma_heatmaps = generate_saliency_batch(images, distiller.student)
# Out:
# CPU times: total: 78.1 ms
# Wall time: 119 ms

# %%
plt.imshow(np.hstack(fma_heatmaps), cmap="jet")

# %%
OUTPUT_FOLDER = "Saliency_Images"
# !mkdir "$OUTPUT_FOLDER"
# Out:
# A subdirectory or file Saliency_Images already exists.

# %%
IMAGE_START = 5

# %%
# !mkdir "$OUTPUT_FOLDER/images"
for img_id, (img, label) in enumerate(zip(images, labels)):
    plt.imsave(f"{OUTPUT_FOLDER}/images/{img_id + IMAGE_START}_{tf.argmax(label)}.jpg", img, cmap="jet")
# Out:
# A subdirectory or file Saliency_Images/images already exists.

# %%
# !mkdir "$OUTPUT_FOLDER/self"
for img_id, (img, label) in enumerate(zip(self_heatmaps, labels)):
    plt.imsave(f"{OUTPUT_FOLDER}/self/{img_id + IMAGE_START}_{tf.argmax(label)}.jpg", img, cmap="jet")
# Out:
# A subdirectory or file Saliency_Images/self already exists.

# %%
# !mkdir "$OUTPUT_FOLDER/vanilla"
for img_id, (img, label) in enumerate(zip(vanilla_heatmaps, labels)):
    plt.imsave(f"{OUTPUT_FOLDER}/vanilla/{img_id + IMAGE_START}_{tf.argmax(label)}.jpg", img, cmap="jet")
# Out:
# A subdirectory or file Saliency_Images/vanilla already exists.

# %%
# !mkdir "$OUTPUT_FOLDER/saliency"
for img_id, (img, label) in enumerate(zip(fma_heatmaps, labels)):
    plt.imsave(f"{OUTPUT_FOLDER}/saliency/{img_id + IMAGE_START}_{tf.argmax(label)}.jpg", img, cmap="jet")
# Out:
# A subdirectory or file Saliency_Images/saliency already exists.
